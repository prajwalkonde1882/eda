# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/student-performance.csv')

# %%
df.shape
# Out:
# (649, 33)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.school.value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
sns.countplot(x = 'school', data = df, palette= 'pastel')
plt.show()
# Out:
# /tmp/ipython-input-2822032450.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'school', data = df, palette= 'pastel')

# %%
sns.countplot(x = 'age', data = df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.histplot(x = 'age', data = df, kde = True, color = 'r')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address.value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
sns.countplot(x = 'address', data = df, color = 'b')
# u = urban, r = rural
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
df.reason.value_counts()
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
reason_count = df.reason.value_counts()
plt.pie(reason_count, labels = reason_count.index, autopct = '%1.1f%%')
plt.show()

# %%
df.sex.value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
sex = df.sex.value_counts()
plt.pie(sex, data = df, labels = sex.index, autopct = '%1.1f%%')
plt.show()

# %%
df.activities.value_counts()
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
sns.histplot(x = 'activities', data = df, color= 'r')
# Out:
# <Axes: xlabel='activities', ylabel='Count'>

# %%
alcho = df.Dalc.value_counts()
plt.pie(alcho, autopct = '%1.1f%%', labels = alcho.index, )
plt.show()

# %%
df.freetime.value_counts()
# Out:
# freetime
# 3    251
# 4    178
# 2    107
# 5     68
# 1     45
# Name: count, dtype: int64

# %%
sns.boxplot(df.freetime)
# Out:
# <Axes: ylabel='freetime'>

# %%
df.studytime
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 644    3
# 645    2
# 646    2
# 647    1
# 648    1
# Name: studytime, Length: 649, dtype: int64

# %%
sns.histplot(df.studytime, )
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.absences.value_counts()
# Out:
# absences
# 0     244
# 2     110
# 4      93
# 6      49
# 8      42
# 10     21
# 12     12
# 1      12
# 5      12
# 16     10
# 14      8
# 9       7
# 3       7
# 11      5
# 7       3
# 18      3
# 15      2
# 22      2
# 21      2
# 24      1
# 32      1
# 30      1
# 26      1
# 13      1
# Name: count, dtype: int64

# %%
df.Pstatus.value_counts()
# Out:
# Pstatus
# T    569
# A     80
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Pstatus', data = df) # A = Apart, T = Living together
plt.show()

# %%
sns.boxplot(data = df, y = 'absences' , x = 'Pstatus')
plt.show()

# %%
df.Fjob.value_counts()
# Out:
# Fjob
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: count, dtype: int64

# %%
counts = df.Fjob.value_counts()
counts.plot(kind = 'bar', color = 'lightblue')
# Out:
# <Axes: xlabel='Fjob'>

# %%
counts = df.Mjob.value_counts()
counts.plot(kind = 'bar', color = 'pink')
# Out:
# <Axes: xlabel='Mjob'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'Dalc'}>,
#         <Axes: title={'center': 'Walc'}>,
#         <Axes: title={'center': 'health'}>],
#        [<Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>, <Axes: title={'center': 'G2'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df.hist(bins = 100, figsize = (10,10), color = 'b')
plt.show()
# All charts of numerical columns

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: count, dtype: int64

# %%
d = df.G1.value_counts()
d.plot(kind = 'bar', color = 'b')
plt.show()

# %%
sns.countplot(df, x= 'age', hue= 'sex')
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.pairplot(df)
plt.show()

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# do urban students score higher than rural students
sns.kdeplot(df.loc[df['address'] == 'U', 'G1'], label = 'Urban', shade = True)
sns.kdeplot(df.loc[df['address'] == 'R', 'G1'], label = 'Rural', shade = True)
plt.title('Performance Comparison for G1')
plt.xlabel('Grade 1')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-3344525774.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address'] == 'U', 'G1'], label = 'Urban', shade = True)
# /tmp/ipython-input-3344525774.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address'] == 'R', 'G1'], label = 'Rural', shade = True)
